# %%
import os
import torch
import librosa
import numpy as np
import pandas as pd
# import soundfile as sf
import IPython.display as ipd

import models
from data import get_SLU_datasets, read_config, SLUDataset

config_path = './unfreeze_word_layers.cfg'
config = read_config(config_path)
_,_,_=get_SLU_datasets(config)

base_path = config.slu_path

# %%
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")

# %% [markdown]
# # 1. Load the SLU Model

# %%
model = models.Model(config).eval()
model.load_state_dict(torch.load("./experiments/unfreeze_word_layers/training/model_state.pth", map_location=DEVICE)) # load trained model
# Out:
# <All keys matched successfully>

# %% [markdown]
# # 2. SLU for Test Dataset

# %%
train_df = pd.read_csv(os.path.join(base_path, "data", "train_data.csv"), index_col=0)
valid_df = pd.read_csv(os.path.join(base_path, "data", "valid_data.csv"), index_col=0)
test_df = pd.read_csv(os.path.join(base_path, "data", "test_data.csv"), index_col=0)
print(f'Train Dataset Size : {len(train_df)}')
print(f'Valid Dataset Size : {len(valid_df)}')
print(f'Test Dataset Size : {len(test_df)}')
# Out:
# Train Dataset Size : 23132
# Valid Dataset Size : 3118
# Test Dataset Size : 3793

# %%
train_df[train_df['transcription'].str.contains('Switch')]
# Out:
#                                                     path         speakerId  \
# 3      wavs/speakers/2BqVo8kVB2Skwgyb/1811b6e0-4474-1...  2BqVo8kVB2Skwgyb
# 4      wavs/speakers/2BqVo8kVB2Skwgyb/1d9f3920-4474-1...  2BqVo8kVB2Skwgyb
# 20     wavs/speakers/2BqVo8kVB2Skwgyb/907594e0-4478-1...  2BqVo8kVB2Skwgyb
# 26     wavs/speakers/2BqVo8kVB2Skwgyb/a7f64650-4478-1...  2BqVo8kVB2Skwgyb
# 28     wavs/speakers/2BqVo8kVB2Skwgyb/ae75f0c0-4478-1...  2BqVo8kVB2Skwgyb
# ...                                                  ...               ...
# 23109  wavs/speakers/zZezMeg5XvcbRdg3/620eaab0-45e0-1...  zZezMeg5XvcbRdg3
# 23127  wavs/speakers/zZezMeg5XvcbRdg3/b946b340-45e0-1...  zZezMeg5XvcbRdg3
# 23128  wavs/speakers/zZezMeg5XvcbRdg3/beb27cb0-45e0-1...  zZezMeg5XvcbRdg3
# 23129  wavs/speakers/zZezMeg5XvcbRdg3/c45f94e0-45e0-1...  zZezMeg5XvcbRdg3
# 23130  wavs/speakers/zZezMeg5XvcbRdg3/ca60c080-45e0-1...  zZezMeg5XvcbRdg3
#
#                                            transcription           action  \
# 3                                   Switch on the lights         activate
# 4                                  Switch off the lights       deactivate
# 20                                    Switch on the lamp         activate
# 26                          Switch on the kitchen lights         activate
# 28                   Switch on the lights in the kitchen         activate
# ...                                                  ...              ...
# 23109                                    Switch language  change language
# 23127  I need to practice my Chinese. Switch the lang...  change language
# 23128  I need to practice my German. Switch the language  change language
# 23129  I need to practice my Korean. Switch the language  change language
# 23130  I need to practice my English. Switch the lang...  change language
#
#         object location
# 3       lights     none
# 4       lights     none
# 20        lamp     none
# 26      lights  kitchen
# 28      lights  kitchen
# ...        ...      ...
# 23109     none     none
# 23127  Chinese     none
# 23128   German     none
# 23129   Korean     none
# 23130  English     none
#
# [2330 rows x 6 columns]

# %%
test_df_samples = test_df.sample(10).reset_index(drop=True)
test_df_samples
# Out:
#                                                 path         speakerId  \
# 0  wavs/speakers/k5bqyxx2lzIbrlg9/ed66b390-4528-1...  k5bqyxx2lzIbrlg9
# 1  wavs/speakers/ppymZZDb2Bf4NQnE/b0a0f130-44f3-1...  ppymZZDb2Bf4NQnE
# 2  wavs/speakers/k5bqyxx2lzIbrlg9/0d65fea0-4527-1...  k5bqyxx2lzIbrlg9
# 3  wavs/speakers/V4ZbwLm9G5irobWn/610afcc0-4524-1...  V4ZbwLm9G5irobWn
# 4  wavs/speakers/V4ejqNL4xbUKkYrV/e6e7be40-459d-1...  V4ejqNL4xbUKkYrV
# 5  wavs/speakers/ppymZZDb2Bf4NQnE/04da2390-44f2-1...  ppymZZDb2Bf4NQnE
# 6  wavs/speakers/k5bqyxx2lzIbrlg9/5d5e7d40-4529-1...  k5bqyxx2lzIbrlg9
# 7  wavs/speakers/V4ZbwLm9G5irobWn/112d2020-4524-1...  V4ZbwLm9G5irobWn
# 8  wavs/speakers/4BrX8aDqK2cLZRYl/79ded690-452e-1...  4BrX8aDqK2cLZRYl
# 9  wavs/speakers/7B4XmNppyrCK977p/5bba89a0-45cb-1...  7B4XmNppyrCK977p
#
#                                        transcription           action  \
# 0                Switch on the lights in the bedroom         activate
# 1  I need to practice my Chinese. Switch the lang...  change language
# 2                                    That’s too loud         decrease
# 3                                   Turn up the heat         increase
# 4                           Use a different language  change language
# 5                                    Kitchen heat up         increase
# 6                                   Turn volume down         decrease
# 7                                 Turn on the lights         activate
# 8                                     Make it hotter         increase
# 9                                          More heat         increase
#
#     object location
# 0   lights  bedroom
# 1  Chinese     none
# 2   volume     none
# 3     heat     none
# 4     none     none
# 5     heat  kitchen
# 6   volume     none
# 7   lights     none
# 8     heat     none
# 9     heat     none

# %%
test_path = os.path.join(base_path, test_df_samples['path'][8])
wav, sr = librosa.load(test_path, sr=None)
ipd.Audio(wav, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
signal = torch.tensor(wav, device=DEVICE).float().unsqueeze(0)
model.decode_intents(signal)
# Out:
# [['increase', 'heat', 'none']]

# %% [markdown]
# # 3. SLU for Custom Utterances

# %%
test_path = "test_wav/test.wav"
wav, sr = librosa.load(test_path, sr=None)
ipd.Audio(wav, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
signal = torch.tensor(wav, device=DEVICE).float().unsqueeze(0)
model.decode_intents(signal)
